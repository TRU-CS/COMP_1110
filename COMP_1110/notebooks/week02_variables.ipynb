# %% [markdown]
# # Week 2 — Variables, Expressions, and Statements
#
# **COMP 1110 — Introduction to Computer Programming**
#
# **Chapter 2 — Variables, expressions and statements**
#
# Tuesday September 15 & Thursday September 17, 2026
# 9:30 – 11:20 AM · Room OM 1241
#
# Instructor: **Quan Nguyen**

# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/TRU-CS/COMP_1110/blob/main/COMP_1110/notebooks/week02_variables.ipynb)
#
# *Run this notebook yourself: press the power button at the top of the page to
# execute cells right here, or click the badge to open an editable copy in Google
# Colab (a Google account is required).*

# %% [markdown]
# ## Where we are
#
# - **Last week (Sep 10):** what a program is, hardware, the Python interpreter,
#   your first `print`.
# - **This week (Sep 15 & 17):** the raw material of every program — values, types,
#   variables, expressions, operators, and getting information from the user.
# - **Next week (Sep 22 & 24):** making decisions with `if` / `elif` / `else` —
#   and project teams are formed on the Thursday.
#
# Worksheet 1 went live this morning at 9:00 and is due Monday, Sep 21 at 11:59 PM.

# %% [markdown]
# ## Today's outcomes
#
# By the end of these two classes you should be able to:
#
# 1. Name the type of a value and predict what `type()` will report. **[CLO 1]**
# 2. Create variables with assignment and trace how their values change. **[CLO 1]**
# 3. Build expressions with arithmetic and string operators, and apply the order
#    of operations correctly. **[CLO 1, CLO 5]**
# 4. Print several values at once, controlling the output with `sep`, `end`
#    and f-strings. **[CLO 1]**
# 5. Read a value with `input()` and convert it with `int()` or `float()`. **[CLO 1]**
# 6. Recognise and repair the common type and naming errors of Chapter 2. **[CLO 4]**

# %% [markdown]
# ## Reading
#
# **[Chapter 2 — Variables, expressions and statements](https://www.py4e.com/html3/02-variables)**
# in *Python for Everybody* (free online edition).
#
# - Read it **before Thursday**, not the night before the worksheet.
# - Read it with VS Code open: **retype each example, change a number,
#   and re-run it.**
# - Do the exercises at the end of the chapter — Worksheet 2 looks a lot like them.
#
# Companion videos: <https://www.py4e.com/>

# %% [markdown]
# ## Values and types
#
# A **value** is the most basic thing a program works with: a number, a piece of text.
# Every value has a **type**, which decides what you may do with it.
#
# | Type | Means | Examples |
# | :--- | :--- | :--- |
# | `int` | whole number | `17`, `0`, `-4` |
# | `float` | number with a decimal point | `3.2`, `98.6`, `-0.5` |
# | `str` | text ("string" of characters) | `"Nadia"`, `'B+'`, `"17"` |
#
# Note the last one: `17` and `"17"` are **not** the same value.

# %%
print(17)
print(3.2)
print("Nadia")

# The quotes are not part of the value - they tell Python "this is text".
print("17")
# Out:
# 17
# 3.2
# Nadia
# 17

# %% [markdown]
# **Careful with commas.** You might write a big number the way you would on paper.
# Python reads commas as separators, not decoration:

# %%
print(1000000)
print(1, 000, 000)
# Out:
# 1000000
# 1 0 0

# %% [markdown]
# ### `type()` tells you what you have
#
# When you are not sure what a value is, ask Python. `type()` is your first
# debugging tool, and you will use it all term.

# %%
print(type(17))
print(type(3.2))
print(type("Nadia"))
print(type("17"))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# `<class 'int'>` is Python's way of saying "this is an integer".
#
# Watch the last line: `"17"` has quotes, so it is a **`str`**, not an `int`.
# That single fact causes more Week 2 bugs than anything else.

# %% [markdown]
# ## Predict the output (1)
#
# No running Python — this is exactly the midterm format.
#
# ```python
# print(type(7))
# print(type(7.0))
# print(type("7"))
# ```
#
# What are the three lines of output?

# %% [markdown]
# **Answer**
#
# ```
# <class 'int'>
# <class 'float'>
# <class 'str'>
# ```
#
# `7` is a whole number. The decimal point alone in `7.0` makes it a `float`.
# Putting `7` in quotes makes it text.

# %% [markdown]
# ## Variables and assignment
#
# A **variable** is a name that refers to a value. You create one with an
# **assignment statement**:
#
# ```python
# quiz_score = 18
# ```
#
# Read `=` as **"gets"**, not "equals": *quiz_score gets the value 18.*
# It is an instruction, not a claim of fact. Name on the **left**, value on the **right**.

# %%
quiz_score = 18
course_name = "COMP 1110"
room_temperature = 21.5

print(course_name)
print(quiz_score)
print(room_temperature)
# Out:
# COMP 1110
# 18
# 21.5

# %% [markdown]
# ### A variable can be reassigned
#
# Assignment is not permanent. A new assignment replaces the old value, and the
# old value is simply gone.

# %%
songs_played = 3
print(songs_played)

songs_played = songs_played + 1
print(songs_played)

songs_played = "many"
print(songs_played, type(songs_played))
# Out:
# 3
# 4
# many <class 'str'>

# %% [markdown]
# Line 4 looks like nonsense in mathematics. In Python it is fine: **the right
# side is worked out first** (`3 + 1` is `4`), then that result is stored back
# into `songs_played`.
#
# The last lines also show a variable's *type* can change. Legal — but usually a
# sign of a confusing program.

# %% [markdown]
# ## Variable names and keywords
#
# Rules Python enforces:
#
# - Letters, digits and underscores only — `total_marks`, `score2`.
# - **Cannot start with a digit.** `2nd_score` is a syntax error.
# - **No spaces, no hyphens.** `quiz score` and `quiz-score` are errors.
# - **Case matters.** `Score` and `score` are two different variables.
# - You cannot use one of Python's **keywords**.

# %% [markdown]
# ### The keywords
#
# ```
# and     as       assert   break    class   continue  def     del
# elif    else     except   False    finally for       from    global
# if      import   in       is       lambda  None      nonlocal not
# or      pass     raise    return   True    try       while   with   yield
# ```
#
# Do not memorise this. Your editor colours keywords differently — if a name you
# typed changes colour, pick another name.

# %%
# Legal names.
final_grade = 88
student_2 = "Ravi"
_hidden = True

print(final_grade, student_2, _hidden)
# Out:
# 88 Ravi True

# %%
# Illegal: a variable name cannot begin with a digit.
2nd_score = 91
# Out:
#   Cell In[7], line 2
#     2nd_score = 91
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ## Statements
#
# A **statement** is a unit of code Python can execute. You already know two kinds:
#
# ```python
# print("hello")        # an expression statement - it produces output
# midterm_mark = 74     # an assignment statement - it produces no output
# ```
#
# A **script** is a sequence of statements run **top to bottom, one at a time**.
# Assignment prints nothing — if you assign and see no output, that is not a bug.

# %%
bus_fare = 2.75          # runs first, prints nothing
trips = 4                # runs second, prints nothing
print(bus_fare * trips)  # runs third, and this one prints
# Out:
# 11.0

# %% [markdown]
# ## Operators and operands
#
# **Operators** are symbols that stand for a computation; **operands** are the
# values they work on. In `price * quantity`, `*` is the operator and
# `price`, `quantity` are the operands.
#
# | Operator | Meaning | on `13` and `4` |
# | :--- | :--- | :--- |
# | `+` `-` `*` | add, subtract, multiply | `17`, `9`, `52` |
# | `/` | division — **always a `float`** | `3.25` |
# | `//` | floor division — drops the remainder | `3` |
# | `%` | modulus — the remainder | `1` |
# | `**` | power | `28561` |

# %%
print(13 + 4)
print(13 - 4)
print(13 * 4)
print(13 / 4)
print(13 // 4)
print(13 % 4)
print(13 ** 4)
# Out:
# 17
# 9
# 52
# 3.25
# 3
# 1
# 28561

# %% [markdown]
# ### `/` versus `//`
#
# In Python 3, `/` **always** gives a `float`, even when the division comes out
# exact. Use `//` when you want a whole number of things.

# %%
print(8 / 2)     # 4.0 - a float, note the .0
print(8 // 2)    # 4   - an int
print(type(8 / 2))

# 100 minutes is how many whole hours, and how many minutes left over?
print(100 // 60, "hours and", 100 % 60, "minutes")
# Out:
# 4.0
# 4
# <class 'float'>
# 1 hours and 40 minutes

# %% [markdown]
# `%` is more useful than it looks: `n % 2` is `0` for every even number, and
# `n % 10` gives you the last digit. We use it in Week 3 and Week 5.

# %% [markdown]
# ## Predict the output (2)
#
# ```python
# minutes = 250
# print(minutes // 60)
# print(minutes % 60)
# print(minutes / 60)
# ```
#
# Three lines. Exactly what does each one print?

# %% [markdown]
# **Answer**
#
# ```
# 4
# 10
# 4.166666666666667
# ```
#
# 250 minutes is 4 whole hours (`//`) with 10 minutes left over (`%`).
# `/` gives the exact answer as a `float` — and floats print a lot of digits.
# Rounding that output is a Week 7 topic.

# %% [markdown]
# ## Expressions
#
# An **expression** is any combination of values, variables and operators that
# Python can reduce to a single value:
#
# ```python
# 17                 # an expression (a value on its own)
# quiz_score         # an expression (a variable on its own)
# quiz_score + 5     # an expression
# ```
#
# Python **evaluates** it down to one value, then prints it or stores it.

# %%
hours_worked = 12
hourly_pay = 17.40

gross_pay = hours_worked * hourly_pay
print(gross_pay)

# An expression can be built from variables you already computed.
take_home = gross_pay * 0.85
print(take_home)
# Out:
# 208.79999999999998
# 177.48

# %% [markdown]
# ## Order of operations
#
# With several operators, Python follows **PEMDAS**:
#
# 1. **P**arentheses
# 2. **E**xponentiation `**`
# 3. **M**ultiplication and **D**ivision (`*`, `/`, `//`, `%`) — left to right
# 4. **A**ddition and **S**ubtraction — left to right
#
# When in doubt, **add parentheses**. They cost nothing and they tell the next
# reader what you meant.

# %%
print(2 + 3 * 4)        # multiplication first
print((2 + 3) * 4)      # parentheses win
print(2 ** 3 ** 2)      # ** goes right to left: 2 ** 9
print(100 - 10 - 5)     # - goes left to right: 90 - 5
# Out:
# 14
# 20
# 512
# 85

# %% [markdown]
# ### A real one: averaging three quizzes
#
# The parentheses here are not optional — they are the whole program.

# %%
quiz_1 = 15
quiz_2 = 18
quiz_3 = 12

wrong_average = quiz_1 + quiz_2 + quiz_3 / 3
right_average = (quiz_1 + quiz_2 + quiz_3) / 3

print("Wrong:", wrong_average)
print("Right:", right_average)
# Out:
# Wrong: 37.0
# Right: 15.0

# %% [markdown]
# ## String operations
#
# `+` and `*` work on strings too, but they mean something different:
#
# - `+` **concatenates** — joins two strings end to end.
# - `*` **repeats** a string a whole number of times.
#
# `-` and `/` do not work on strings at all.

# %%
first_name = "Amara"
last_name = "Okafor"

full_name = first_name + " " + last_name
print(full_name)

print("-" * 30)
print("ha" * 3)
# Out:
# Amara Okafor
# ------------------------------
# hahaha

# %% [markdown]
# Notice the `" "` in the middle: concatenation adds **nothing** of its own, so a
# space between two words is yours to supply.

# %% [markdown]
# ### `print` with commas versus `+`
#
# Two ways to print several things — and they are not the same.

# %%
city = "Kamloops"
high_temp = 27

# Commas: print puts a space between items and accepts any type.
print(city, "high today:", high_temp)

# Plus: joins strings only - every piece must already be a string.
print(city + " high today: " + str(high_temp))
# Out:
# Kamloops high today: 27
# Kamloops high today: 27

# %% [markdown]
# ## Predict the output (3)
#
# ```python
# print("3" + "4")
# print(3 + 4)
# print("3" * 4)
# ```
#
# Three lines. What comes out?

# %% [markdown]
# **Answer**
#
# ```
# 34
# 7
# 3333
# ```
#
# - `"3" + "4"` — both strings, so `+` **joins** them into the text `34`.
# - `3 + 4` — both ints, so `+` **adds**: `7`.
# - `"3" * 4` — string times int **repeats** the string four times.
#
# Same operators, different types, completely different answers. **Types matter.**

# %% [markdown]
# ## A closer look at `print`
#
# You have been giving `print` one thing at a time. Its full shape is:
#
# ```python
# print(*objects, sep=' ', end='\n')
# ```
#
# - `*objects` — **as many values as you like**, separated by commas.
#   Any types, mixed freely; `print` converts each one to text for you.
# - `sep` — what goes **between** the values. Default: one space.
# - `end` — what goes **after** the last one. Default: a newline, `\n`.
#
# `sep` and `end` are **keyword arguments**: you name them in the call, and
# you only mention the one you want to change.

# %%
city = "Kamloops"
high = 27
low = 14

# *objects: any number of values, any mix of types.
print(city, high, low, "degrees")

# sep replaces the space that print puts between them.
print(city, high, low, sep=" | ")
print(2026, 9, 15, sep="-")
print("no", "gaps", "at", "all", sep="")
# Out:
# Kamloops 27 14 degrees
# Kamloops | 27 | 14
# 2026-9-15
# nogapsatall

# %% [markdown]
# `sep` appears **between** items only — never before the first or after the
# last. So `sep` does nothing at all when you print a single value.
#
# And `print()` with no values prints nothing but the `end` — which is how you
# get a blank line.

# %% [markdown]
# ### `end` — what comes after the line
#
# Every `print` finishes with a newline, which is why each call starts a fresh
# line. Change `end` and the next `print` carries on where this one stopped:
#
# - `end=""` — stay on the same line.
# - `end=" "` — stay on the same line, one space along.
# - `end="\n\n"` — leave a blank line behind.
#
# This matters in Week 5, when a loop prints one item per pass and you want
# them side by side.

# %%
# The default: each print ends the line, so each gets a line of its own.
print("Loading")
print("done")

# end="" keeps the next print on the same line.
print("Loading", end="")
print("...", end="")
print("done")

# end can be any text you like.
print("Kamloops", end=" -> ")
print(high)

# sep and end together.
print("a", "b", "c", sep="-", end="!\n")
# Out:
# Loading
# done
# Loading...done
# Kamloops -> 27
# a-b-c!

# %% [markdown]
# Line 6–8 print on one line because the first two calls end with nothing.
# The very last `print` of a group still needs its newline — otherwise your
# next output arrives glued to the end of it.

# %% [markdown]
# ### f-strings — the value inside the sentence
#
# Commas and `+` both work, but both get clumsy once a sentence carries
# several values. An **f-string** is a string with an `f` in front of the
# opening quote. Inside it, anything in `{ }` is worked out by Python and
# dropped into the text:
#
# ```python
# print(f"{city} hit {high} degrees today.")
# ```
#
# - No `str()` calls — every type is converted for you.
# - No spaces to count — what you type between the braces is what you get.
#
# We return to f-strings properly in **Week 7**, including how to show money
# as `$14.28` instead of all the digits a `float` happens to carry.

# %%
city = "Kamloops"
high = 27
price_each = 4.25
cups = 3

# The same sentence three ways.
print(city, "hit", high, "degrees.")
print(city + " hit " + str(high) + " degrees.")
print(f"{city} hit {high} degrees.")

# The braces hold an expression, so it can do arithmetic.
print(f"{cups} coffees at ${price_each} each = ${cups * price_each}")

# A float prints every digit it has - Week 7 shows how to round the display.
print(f"With 12% tax: ${cups * price_each * 1.12}")
# Out:
# Kamloops hit 27 degrees.
# Kamloops hit 27 degrees.
# Kamloops hit 27 degrees.
# 3 coffees at $4.25 each = $12.75
# With 12% tax: $14.280000000000001

# %% [markdown]
# Forget the `f` and you get the braces themselves, printed literally —
# `{city} hit {high} degrees.` No error message, just wrong output. It is a
# semantic error, and the fix is one character.

# %% [markdown]
# ## Predict the output (4)
#
# ```python
# print("a", "b", "c", sep="")
# print(1, 2, sep="+", end=" = ")
# print(3)
#
# n = 5
# print(f"{n} squared is {n * n}")
# ```
#
# How many lines of output, and what are they?

# %% [markdown]
# **Answer** — three lines:
#
# ```
# abc
# 1+2 = 3
# 5 squared is 25
# ```
#
# - `sep=""` removes the spaces: `abc`.
# - Line 2 ends with `" = "` instead of a newline, so line 3's `3` lands on
#   the same line — two calls, one line of output.
# - `{n * n}` is an expression: Python works out `25` before printing.

# %% [markdown]
# ## Asking the user for input
#
# `input()` pauses the program, waits for the user to type a line, and hands that
# line back as a value:
#
# ```python
# name = input("What is your name? ")
# print("Hello,", name)
# ```
#
# The text in the parentheses is the **prompt**. End prompts with a space so the
# typing is not jammed against the question.

# %% [markdown]
# A real `input()` would freeze these slides waiting for a keyboard, so here we
# simulate it: assign the variable directly with a comment saying what the user
# typed. **In your own scripts, use the real `input()`.**

# %%
# In a real script this line would be:
#     name = input("What is your name? ")
name = "Sam"          # imagine the user typed this

print("Hello,", name)
print(type(name))
# Out:
# Hello, Sam
# <class 'str'>

# %% [markdown]
# ## `input()` always gives you a `str`
#
# This is the single most important sentence of Week 2.
#
# Even when the user types `42`, what comes back is the **text** `"42"`, not the
# number `42`. Python does not guess what you meant.

# %%
# raw_age = input("How old are you? ")   <- the real line
raw_age = "42"        # imagine the user typed 42

print(raw_age)
print(type(raw_age))

# So this does NOT do arithmetic:
print(raw_age + "1")
# Out:
# 42
# <class 'str'>
# 421

# %% [markdown]
# ## Type conversion: `int()`, `float()`, `str()`
#
# | Call | Gives you | Example |
# | :--- | :--- | :--- |
# | `int(x)` | a whole number | `int("42")` → `42` |
# | `float(x)` | a decimal number | `float("3.5")` → `3.5` |
# | `str(x)` | text | `str(42)` → `"42"` |
#
# The rule: **convert as soon as the value arrives**, then work with real numbers
# for the rest of the program.

# %%
raw_age = "42"           # what input() would have handed you

age = int(raw_age)       # convert once, right away
print(age, type(age))

print("Next year you will be", age + 1)
# Out:
# 42 <class 'int'>
# Next year you will be 43

# %%
print(int("42"))         # str  -> int
print(float("3.5"))      # str  -> float
print(str(42) + "!")     # int  -> str, so + can join it
print(int(3.9))          # float-> int: chops off, does NOT round
print(float(7))          # int  -> float
# Out:
# 42
# 3.5
# 42!
# 3
# 7.0

# %% [markdown]
# ### The classic bug: `"3" + 4`
#
# Half the class will hit this in Worksheet 2. Here it is on purpose.

# %%
# quantity = input("How many coffees? ")   <- the real line
quantity = "3"          # imagine the user typed 3

total_cups = quantity + 4
print(total_cups)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       1 # quantity = input("How many coffees? ")   <- the real line
#       2 quantity = "3"          # imagine the user typed 3
#       3
# ----> 4 total_cups = quantity + 4
#       5 print(total_cups)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ```
# TypeError: can only concatenate str (not "int") to str
# ```
#
# Python is saying: *the left side is text, so `+` means "join" — and I cannot
# join a number onto text.* **The fix is one call:** convert before you compute.

# %%
quantity = "3"          # imagine the user typed 3

total_cups = int(quantity) + 4
print(total_cups)
# Out:
# 7

# %% [markdown]
# ### Conversion can fail too
#
# `int()` needs text that really is a whole number.

# %%
print(int("42"))       # fine
print(int(" 42 "))     # fine - surrounding spaces are ignored
print(int("forty"))    # not fine
# Out:
# 42
# 42
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 3
#       1 print(int("42"))       # fine
#       2 print(int(" 42 "))     # fine - surrounding spaces are ignored
# ----> 3 print(int("forty"))    # not fine
#
# ValueError: invalid literal for int() with base 10: 'forty'

# %% [markdown]
# `ValueError: invalid literal for int() with base 10: 'forty'` means
# "you promised me a number and gave me a word."
#
# Handling that gracefully instead of crashing is `try` / `except` — **next week**.

# %% [markdown]
# ## Comments
#
# Anything after a `#` on a line is ignored by Python. It is there for **people**.
#
# ```python
# # Convert the raw input to a number before doing arithmetic.
# age = int(raw_age)
# ```
#
# Write comments that explain **why**, not **what**. The code already says what it
# does; it cannot say why you chose to do it.

# %%
# BAD - just re-reads the code out loud.
seconds = 7200      # set seconds to 7200

# GOOD - explains the reason and the units.
seconds = 7200      # the two-hour lab booking, in seconds

hours = seconds // 3600
print("Booking length:", hours, "hours")
# Out:
# Booking length: 2 hours

# %% [markdown]
# ## Choosing mnemonic variable names
#
# *Mnemonic* means **memory-aiding**. A good name reminds the reader — usually
# you, three weeks later — what the value is for.
#
# ```python
# x = 0.13 * 24.99          # what on earth is this?
# tax = 0.13 * item_price   # oh, it is sales tax
# ```
#
# Python does not care; it runs both. **Your marker cares** — worksheets are
# graded for readable code as well as correct output.

# %%
# Hard to read - and just as hard to debug.
a = 24.99
b = 3
c = a * b
print(c)
# Out:
# 74.97

# %%
# Same arithmetic, but the program now explains itself.
item_price = 24.99
item_count = 3

subtotal = item_price * item_count
print("Subtotal:", subtotal)
# Out:
# Subtotal: 74.97

# %% [markdown]
# ### Habits to start now
#
# - Use whole words: `student_count`, not `sc` or `n1`.
# - Separate words with underscores: `final_grade`. This is called **snake_case**.
# - Put spaces around operators: `total = price * quantity`, not `total=price*quantity`.
# - Avoid single letters except for genuine counters (`i` in a loop, from Week 5).
#
# Python has a written style guide and we spend all of **Week 13** on it. For now
# just build the habits — you will get the rules for free later.

# %% [markdown]
# ## Debugging
#
# Three kinds of error, and they fail in different ways:
#
# | Kind | When it bites | Example |
# | :--- | :--- | :--- |
# | **Syntax** | before anything runs | `print("hi"` — missing bracket |
# | **Runtime** | part-way through | `int("forty")` — `ValueError` |
# | **Semantic** | never — it just gives a wrong answer | `q1 + q2 + q3 / 3` |
#
# The third is the dangerous one: Python is perfectly happy, and only you can
# notice the answer is wrong.

# %% [markdown]
# ### A method that works
#
# 1. **Read the error from the bottom up.** The last line names the error type;
#    the line above gives the line number.
# 2. **Print the variable and its type** just before the line that failed:
#    `print(quantity, type(quantity))`.
# 3. **Cut the program in half.** Comment out the bottom — does the top still work?
# 4. **Say the line out loud.** "quantity gets the string three." Often that is enough.
# 5. **Take a break.** Ten minutes away beats an hour of staring.

# %% [markdown]
# ## Live coding 1 — the coffee run
#
# Together, in class. Start from the empty cell below.

# %%
# Problem: you are picking up coffee for the study group.
# The user tells us how many coffees they want.
# Each coffee costs $4.25 and sales tax is 12%.
# Print the number of coffees, the subtotal, and the total with tax.
#
# Remember: input() hands you a str.

coffees_typed = "4"      # imagine the user typed this

# %%
# Solution
# coffees_typed = input("How many coffees? ")
coffees_typed = "4"          # imagine the user typed this

coffee_count = int(coffees_typed)
price_each = 4.25
tax_rate = 0.12

subtotal = coffee_count * price_each
total = subtotal + subtotal * tax_rate

print("Coffees:", coffee_count)
print("Subtotal:", subtotal)
print("Total with tax:", total)
# Out:
# Coffees: 4
# Subtotal: 17.0
# Total with tax: 19.04

# %% [markdown]
# ## Live coding 2 — seconds to a readable time
#
# Together. This one is all `//` and `%`.

# %%
# Problem: a podcast episode is 9042 seconds long.
# Print it as hours, minutes and seconds:
#     2 hours, 30 minutes, 42 seconds
#
# Hints: 3600 seconds in an hour, 60 in a minute.
#        // gives whole units, % gives what is left over.

total_seconds = 9042

# %%
# Solution
total_seconds = 9042

hours = total_seconds // 3600
remaining = total_seconds % 3600
minutes = remaining // 60
seconds = remaining % 60

print(hours, "hours,", minutes, "minutes,", seconds, "seconds")
# Out:
# 2 hours, 30 minutes, 42 seconds

# %% [markdown]
# ## Common errors this week
#
# **1. Adding a string to a number**
#
# ```python
# total = quantity + 4      # quantity came from input()
# ```
# ```
# TypeError: can only concatenate str (not "int") to str
# ```
# *Meaning:* the left operand is text, so `+` tried to join rather than add.
# **Fix:** `int(quantity) + 4`.

# %% [markdown]
# **2. Using a variable you never assigned (or misspelled)**

# %%
student_name = "Priya"
print(studnet_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 student_name = "Priya"
# ----> 2 print(studnet_name)
#
# NameError: name 'studnet_name' is not defined

# %% [markdown]
# `NameError: name 'studnet_name' is not defined` — Python has never seen that
# name. **Fix:** check the spelling *and* the capitals; `Name` and `name` differ.

# %% [markdown]
# **3. Assigning in the wrong direction**

# %%
17 = quiz_score
# Out:
#   Cell In[34], line 1
#     17 = quiz_score
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [markdown]
# `SyntaxError: cannot assign to literal here.` — the name must be on the
# **left** of the `=`. **Fix:** `quiz_score = 17`.

# %% [markdown]
# **4. The one Python will not warn you about**
#
# ```python
# average = quiz_1 + quiz_2 + quiz_3 / 3
# ```
#
# No error message. No red text. Just a wrong number, silently, forever.
# **Fix:** `(quiz_1 + quiz_2 + quiz_3) / 3` — and always check one answer by hand.

# %% [markdown]
# ## Summary
#
# - Every value has a **type**: `int`, `float`, `str`. Ask `type()` when unsure.
# - `=` means **"gets"**: the right side is evaluated first, then stored in the
#   name on the left.
# - Operators `+ - * **`, plus `/` (always a float), `//` (whole), `%` (remainder).
#   Parentheses beat everything.
# - On strings, `+` **joins** and `*` **repeats** — same symbol, different job.
# - `print(*objects, sep=' ', end='\n')`: many values at once, `sep` between
#   them, `end` after the last. An f-string puts the values in the sentence.
# - **`input()` always returns a `str`** — convert with `int()` or `float()`
#   immediately, or you get a `TypeError`.
# - Mnemonic names and *why* comments are part of a correct answer, not decoration.

# %% [markdown]
# ## Worksheet 2
#
# **Released:** Tuesday Sep 22, 9:00 AM · **Due:** Monday Sep 28, **11:59 PM**
#
# It covers exactly this week's material:
#
# - Naming types and predicting `type()` output.
# - Arithmetic with `/`, `//`, `%` and the order of operations.
# - A short program that takes input, converts it, and prints a computed result.
# - One **trace-and-explain** question: find the type bug and fix it.
#
# Graded for correct output **and** readable code. Budget 60–90 minutes, and start
# Thursday rather than Monday night.

# %% [markdown]
# ## Next class — Week 3 (Sep 22 & 24)
#
# **Chapter 3: Conditionals.** Boolean expressions, comparison and logical
# operators, `if` / `elif` / `else`, nested conditionals, and `try` / `except` —
# which is how we finally stop `int("forty")` from crashing a program.
#
# **Also on Thursday Sep 24: project teams are due.** Teams of 3–4. Start looking
# around the room now — your team is also your study group for the rest of the term.
#
# Read [Chapter 3](https://www.py4e.com/html3/03-conditional) before Tuesday.
