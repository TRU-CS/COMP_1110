# %% [markdown]
# # Worksheet 9 — The Lyric Lab
#
# **COMP 1110 — Introduction to Computer Programming · Fall 2026**
# Instructor: **Quan Nguyen** · lnguyen[at]tru[dot]ca
#
# | | |
# | :--- | :--- |
# | **Covers** | dictionaries, the counting pattern, `get`, looping over keys and values |
# | **Reading** | [Chapter 9 — Dictionaries](https://books.trinket.io/pfe/09-dictionaries.html) |
# | **Released** | Tuesday, November 10, 2026 |
# | **Due** | **Tuesday, November 17, 9:00 AM** — on Moodle, before class |
# | **Worth** | 2% (your lowest worksheet score is dropped) |
#
# **Your name:** *(double-click this cell and type it here)*
#
# **Your student number:**

# %% [markdown]
# ## How to use this worksheet
#
# 1. **Run every cell as you go** — `Shift`+`Enter`. Nothing happens until you run it.
# 2. Wherever you see `# TODO`, that is your job. Replace it with your own code.
# 3. Cells marked **✅ Self-check** test your answer. If a self-check prints
#    `All checks passed`, that exercise is done. If it raises an `AssertionError`,
#    read the message — it tells you what was expected.
# 4. **Save before submitting** (`Ctrl`/`Cmd`+`S`), then upload this `.ipynb` file to Moodle.
#
# ### The rules (from the syllabus)
#
# - Talking through *approaches* with classmates is encouraged. **Writing the code together, or
#   copying it, is not.** Every line you submit must have come off your own keyboard.
# - If you used an AI tool, fill in the acknowledgement at the bottom. You must be able to
#   explain every line you submit — the midterms are closed-book, with no AI.
# - Marks are for **correct code** *and* **readable code**: meaningful names, and a comment
#   wherever the logic is not obvious.
#
# ⏱️ **Budget:** 60–90 minutes if you have done the reading. Stuck for more than 15 minutes on
# one part? Post on the Moodle forum — include your code *and* the full error message.

# %% [markdown]
# ### Released Tuesday this week
#
# There is **no class on Thursday November 12** (fall mid-term break), so this worksheet goes out
# after Tuesday's class instead. It is still due the following Tuesday, **November 17** — the
# class before **Midterm 2 on Thursday November 19**. Use it as revision.
#
# ### Why dictionaries
#
# A list finds things by **position**: `scores[3]`. A dictionary finds things by **name**:
# `scores["ada"]`. Almost every "how many of each?" question in programming is a dictionary, and
# you are about to see how much shorter it makes things.

# %% [markdown]
# ### This worksheet writes its own data
#
# Run this first.

# %%
lyrics = open("song.txt", "w")
lyrics.write("the wheels on the bus go round and round\n")
lyrics.write("round and round round and round\n")
lyrics.write("the wheels on the bus go round and round\n")
lyrics.write("all through the town\n")
lyrics.close()

print("Data file written.")

# %% [markdown]
# ---
#
# ## 🔥 Warm-up — Predict the output

# %% [markdown]
# ### Warm-up 1
#
# ```python
# ages = {"ada": 36, "grace": 45}
# print(ages["ada"])
# ages["linus"] = 24
# ages["ada"] = 37
# print(len(ages))
# print(ages)
# ```

# %% [markdown]
# **Your prediction:** *(three lines — did `ages["ada"] = 37` add a key or change one?)*

# %%
ages = {"ada": 36, "grace": 45}
print(ages["ada"])
ages["linus"] = 24
ages["ada"] = 37
print(len(ages))
print(ages)

# %% [markdown]
# ### Warm-up 2 — the error you will meet a hundred times
#
# ```python
# ages = {"ada": 36}
# print(ages["margaret"])
# ```

# %% [markdown]
# **Your prediction:** *(which error, and what does it name?)*

# %%
ages = {"ada": 36}
print(ages["margaret"])

# %% [markdown]
# ### Warm-up 3 — `get` is the fix
#
# ```python
# ages = {"ada": 36}
# print(ages.get("margaret"))
# print(ages.get("margaret", 0))
# print("ada" in ages)
# print("margaret" in ages)
# ```

# %% [markdown]
# **Your prediction:** *(four lines)*

# %%
ages = {"ada": 36}
print(ages.get("margaret"))
print(ages.get("margaret", 0))
print("ada" in ages)
print("margaret" in ages)

# %% [markdown]
# **Q1 (written).** In one sentence: what is the difference between `ages["x"]` and
# `ages.get("x", 0)`, and when would you deliberately want the version that crashes?
#
# *Your answer:*

# %% [markdown]
# ---
#
# ## Part A — The counting pattern
#
# This is the pattern. Learn it once, use it forever:
#
# ```python
# counts = {}
# for item in things:
#     counts[item] = counts.get(item, 0) + 1
# ```
#
# Three lines that answer "how many of each?" for anything.

# %% [markdown]
# ### A1 — Count the letters
#
# Write `letter_counts(text)` returning a dictionary mapping each **letter** to how many times it
# appears. Ignore spaces and punctuation, and treat upper and lower case as the same letter.
#
# `letter_counts("Abba!")` returns `{"a": 2, "b": 2}`.

# %%
# TODO: define letter_counts(text)

# %%
# ✅ Self-check A1
assert letter_counts("Abba!") == {"a": 2, "b": 2}
assert letter_counts("") == {}
assert letter_counts("   ") == {}, "spaces are not letters"
assert letter_counts("Mississippi")["s"] == 4
assert "!" not in letter_counts("hi!")
print("All checks passed")

# %% [markdown]
# ### A2 — Count the words
#
# Write `word_counts(text)` doing the same for words. Lowercase everything, and strip the
# punctuation `.,!?` off the ends of words so that `"town."` and `"town"` are the same word.
#
# That last requirement is the one everyone forgets, and it is the reason your answer will differ
# from your classmates' in Part D.

# %%
# TODO: define word_counts(text)

# %%
# ✅ Self-check A2
counts = word_counts("The bus, the BUS! the bus.")
assert counts == {"the": 3, "bus": 3}, "got " + str(counts)
assert word_counts("") == {}
assert word_counts("a a a b")["a"] == 3
print("All checks passed")

# %% [markdown]
# ### A3 — The champion word
#
# Write `most_common(counts)` which takes a counting dictionary and returns the key with the
# largest value. If two keys tie, return whichever you like — but say what your rule is in the
# docstring.
#
# This is "largest so far" from Week 5 for the third time. Notice that you now recognise the
# pattern instantly. That is what learning to program feels like.

# %%
# TODO: define most_common(counts)

# %%
# ✅ Self-check A3
assert most_common({"a": 3, "b": 9, "c": 1}) == "b"
assert most_common({"only": 1}) == "only"
assert most_common({}) is None, "an empty dictionary has no champion - return None"
assert most_common.__doc__ is not None, "docstrings are expected from Week 8 onwards"
print("All checks passed")

# %% [markdown]
# ---
#
# ## 🎤 Part B — The Lyric Lab
#
# Now point your three functions at a real file and find out things nobody told you.

# %% [markdown]
# ### B1 — Read the song
#
# Write `read_text(filename)` returning the whole file as **one** string.
#
# (You have `.read()` for this, and you also know how to loop and concatenate. Either is fine —
# but say in a comment which you used and why.)

# %%
# TODO: define read_text(filename)

# %%
# ✅ Self-check B1
song = read_text("song.txt")
assert type(song) == str
assert "wheels" in song
assert song.count("round") == 8, "counted " + str(song.count("round"))
print("All checks passed")

# %% [markdown]
# ### B2 — The report
#
# Write `report(filename)` which prints a summary like this (your numbers will be the real ones):
#
# ```text
# Total words:        28
# Different words:    10
# Most common word:   round (8 times)
# Longest word:       through
# ```
#
# Line it up with f-strings — you have had them since Week 7 and a report that does not line up
# looks careless.

# %%
# TODO: define report(filename)

# %%
report("song.txt")

# %% [markdown]
# ### B3 — Top five 🏅
#
# Write `top_five(counts)` which **prints** the five most common words with their counts, most
# common first, as a little bar chart:
#
# ```text
# round         8  ########
# the           5  #####
# and           3  ###
# ```
#
# You do not have `sorted()` on dictionaries until next week, so do it the honest way: find the
# champion with `most_common`, print it, remove it from a **copy** of the dictionary, repeat five
# times.
#
# Use `dict(counts)` to copy — remember Week 8: assigning does not copy, and destroying the
# caller's dictionary would be rude.

# %%
# TODO: define top_five(counts)

# %%
song_counts = word_counts(read_text("song.txt"))
before = dict(song_counts)
top_five(song_counts)
assert song_counts == before, "top_five must not destroy the dictionary it was given"
print("All checks passed")

# %% [markdown]
# **Q2 (written).** The most common words in almost any English text are `the`, `and`, `of`, `to`,
# `a`. Are they interesting? What would you have to do to make the top five actually tell you what
# the text is *about*? (Two or three sentences — this is a real technique with a name, and you can
# implement it in the bonus.)
#
# *Your answer:*

# %% [markdown]
# ### B4 — The signature 🕵️
#
# Different texts have different "fingerprints". Write `average_word_length(text)` returning the
# mean length of the words, to one decimal.
#
# Then run it on the song, on a paragraph of your own writing, and on a paragraph from the
# textbook. Record the three numbers.

# %%
# TODO: define average_word_length(text)

# %%
# ✅ Self-check B4
assert average_word_length("a bb ccc") == 2.0
assert average_word_length("") == 0, "no words, no average - do not crash"
print("Song:", average_word_length(read_text("song.txt")))
print("All checks passed")

# %%
my_paragraph = """
TODO: paste a paragraph of your own writing here.
"""

textbook_paragraph = """
TODO: paste a paragraph from Python for Everybody here.
"""

print("Song:     ", average_word_length(read_text("song.txt")))
print("Me:       ", average_word_length(my_paragraph))
print("Textbook: ", average_word_length(textbook_paragraph))

# %% [markdown]
# **Q3 (written).** Which of the three had the longest average word, and does that match your
# intuition about which is "hardest" to read?
#
# *Your answer:*

# %% [markdown]
# ---
#
# ## 🐛 Part C — Trace and explain

# %% [markdown]
# ### C1 — Find the bug
#
# This is meant to count words and it crashes on the second word.

# %%
words = ["red", "blue", "red"]
counts = {}
for word in words:
    counts[word] = counts[word] + 1
print(counts)

# %% [markdown]
# **Q4 (written).** Name the error and say exactly which word triggered it and why. Then give
# **two** different one-line fixes (one using `get`, one using `in`).
#
# *Your answer:*

# %%
# TODO: fix 1, using .get()

# %%
# TODO: fix 2, using `in`

# %% [markdown]
# ### C2 — Trace by hand
#
# ```python
# inventory = {"potion": 2, "sword": 1}
# inventory["potion"] = inventory["potion"] - 1
# inventory["shield"] = inventory.get("shield", 0) + 1
# del inventory["sword"]
# print(len(inventory))
# print(inventory)
# ```
#
# **Without running it**, list the dictionary's contents after each line:
#
# | After line | Contents |
# | :--- | :--- |
# | 1 | |
# | 2 | |
# | 3 | |
# | 4 | |
#
# *Your answer:*

# %%
# Check yourself.
inventory = {"potion": 2, "sword": 1}
inventory["potion"] = inventory["potion"] - 1
inventory["shield"] = inventory.get("shield", 0) + 1
del inventory["sword"]
print(len(inventory))
print(inventory)

# %% [markdown]
# ### C3 — The subtle one
#
# ```python
# counts = {"a": 1, "b": 2, "c": 3}
# for key in counts:
#     if counts[key] < 2:
#         del counts[key]
# print(counts)
# ```
#
# **Q5 (written).** Run it. This is the dictionary version of the Week 8 bug where you removed
# items from a list while looping over it — but the error message is different and more direct.
# What is it, and what is the standard fix?
#
# *Your answer:*

# %%
counts = {"a": 1, "b": 2, "c": 3}
for key in counts:
    if counts[key] < 2:
        del counts[key]
print(counts)

# %%
# TODO: the version that works

# %% [markdown]
# ---
#
# ## 🤝 Part D — Team Arena: The Class Corpus
#
# **Moodle forum thread: `Week 9 — The Class Corpus`.**
#
# Everybody in this class is about to run **the same code on the same text** — and get different
# answers. Finding out why is the exercise.
#
# ### Round 1 — Same text, same answer?
#
# The text is `song.txt`, which every one of you has an identical copy of. Post:
#
# - your **total word count**
# - your **number of different words**
# - your **top three words with counts**
#
# Then read the thread. Wherever two people disagree, **one of them has a bug** — almost certainly
# in punctuation stripping or lowercasing. Reply to somebody whose numbers differ from yours and
# work out together *which* word is being counted differently. Do not post fixed code; post the
# **word** that differs.
#
# ### Round 2 — Bring your own text 📚
#
# Post a link to (or a paragraph of) a public text — song lyrics you like, a news article, a
# Wikipedia paragraph. Then run **your** analyser on **three other people's** texts and post:
#
# - the top three words
# - the average word length
# - your one-sentence guess at what the text is about, based only on the counts
#
# **Bounty:** the text whose top words give away its subject most obviously wins. The text where
# the counts tell you *nothing* is the more interesting result, and I want to see one of those in
# class on Tuesday.

# %% [markdown]
# **Q6 (written).** Did your numbers for `song.txt` match the class's? If not, what was the
# difference, and which of you was right?
#
# *Your answer:*

# %% [markdown]
# ---
#
# ## 📝 Midterm 2 is Thursday, November 19
#
# Midterm 2 covers **Chapters 6–10** — strings, files, lists, dictionaries, tuples — plus testing
# and docstrings. It is **closed-book, 60 minutes, on Moodle, and you may not run Python.**
#
# The parts of this worksheet that rehearse it are the **warm-ups** and **Part C**. If you can
# predict a `KeyError` before it happens, you are in good shape. Tuesday's class (Nov 17) is a
# review class — bring the questions you got wrong here.

# %% [markdown]
# ---
#
# ## ⭐ Bonus (0 marks) — Words that actually matter
#
# Make a **stop-word list** — `the`, `and`, `a`, `of`, `to`, `on`, `in`, `is` — and ignore those
# words when counting. Re-run the top five on your own text.
#
# That single change is the difference between "the top word is *the*" and a summary that tells
# you something. It is also the first thing every real text-analysis tool does.

# %%
# TODO (optional): top_five_interesting(text)

# %% [markdown]
# ---
#
# ## ✅ Before you submit
#
# Tick each one by replacing `[ ]` with `[x]` (double-click this cell to edit):
#
# - [ ] My name and student number are at the top.
# - [ ] I ran **every** cell from top to bottom, in order, with no errors.
# - [ ] Every **✅ Self-check** cell printed `All checks passed`.
# - [ ] I answered the written questions (they are marks too, not decoration).
# - [ ] I posted my counts in **Week 9 — The Class Corpus** and compared them with classmates'.
# - [ ] My variables have meaningful names — no `x`, `a`, `thing`.
# - [ ] I saved the notebook, and I am uploading the `.ipynb` file (not a screenshot, not a PDF).
#
# **Restart & Run All** is the honest test: *Kernel → Restart Kernel and Run All Cells*.
# If it fails there, it will fail when I mark it.

# %% [markdown]
# ## 🤖 AI acknowledgement
#
# Delete whichever line does not apply.
#
# > I did not use any AI tool on this worksheet.
#
# > **AI Acknowledgement:** This worksheet was completed with assistance from *[tool name and
# > version]*. I used it for *[e.g. explaining an error message, extra practice problems]*. All
# > AI-generated content was reviewed, verified, and edited by me, and I can explain every line
# > of the code I submitted.

# %% [markdown]
# ---
#
# ### Coming next
#
# **Week 11 — Tuples and sets.** Sorting a dictionary properly (finally), and the data structure that answers "what do we have in common?". Read [Chapter 10](https://books.trinket.io/pfe/10-tuples.html) plus the set notes on Moodle. **Midterm 2 is Thursday November 19.**
#
# *Worksheet 9 of 11 · COMP 1110 · Fall 2026 · Quan Nguyen*
