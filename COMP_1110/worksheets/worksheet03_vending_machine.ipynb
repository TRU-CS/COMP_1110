# %% [markdown]
# # Worksheet 3 — The Vending Machine
#
# **COMP 1110 — Introduction to Computer Programming · Fall 2026**
# Instructor: **Quan Nguyen** · lnguyen[at]tru[dot]ca
#
# | | |
# | :--- | :--- |
# | **Covers** | boolean expressions, `if` / `elif` / `else`, nested conditions, `try` / `except` |
# | **Reading** | [Chapter 3 — Conditional execution](https://books.trinket.io/pfe/03-conditional.html) |
# | **Released** | Thursday, September 24, 2026 |
# | **Due** | **Tuesday, September 29, 9:00 AM** — on Moodle, before class |
# | **Worth** | 2% (your lowest worksheet score is dropped) |
#
# **Your name:** *(double-click this cell and type it here)*
#
# **Your student number:**

# %% [markdown]
# ## How to use this worksheet
#
# 1. **Run every cell as you go** — `Shift`+`Enter`. Nothing happens until you run it.
# 2. Wherever you see `# TODO`, that is your job. Replace it with your own code.
# 3. Cells marked **✅ Self-check** test your answer. If a self-check prints
#    `All checks passed`, that exercise is done. If it raises an `AssertionError`,
#    read the message — it tells you what was expected.
# 4. **Save before submitting** (`Ctrl`/`Cmd`+`S`), then upload this `.ipynb` file to Moodle.
#
# ### The rules (from the syllabus)
#
# - Talking through *approaches* with classmates is encouraged. **Writing the code together, or
#   copying it, is not.** Every line you submit must have come off your own keyboard.
# - If you used an AI tool, fill in the acknowledgement at the bottom. You must be able to
#   explain every line you submit — the midterms are closed-book, with no AI.
# - Marks are for **correct code** *and* **readable code**: meaningful names, and a comment
#   wherever the logic is not obvious.
#
# ⏱️ **Budget:** 60–90 minutes if you have done the reading. Stuck for more than 15 minutes on
# one part? Post on the Moodle forum — include your code *and* the full error message.

# %% [markdown]
# ### How to test a decision
#
# A program with an `if` in it behaves differently for different inputs, so **one run proves
# almost nothing**. Throughout this worksheet you will change the value at the top of a cell and
# re-run it, several times, to check every branch.
#
# Yes, that is tedious. Hold that thought — **Week 4 introduces functions**, which exist partly
# to make this stop being tedious.

# %% [markdown]
# ---
#
# ## 🔥 Warm-up — Predict the output

# %% [markdown]
# ### Warm-up 1
#
# ```python
# temperature = 15
# if temperature > 30:
#     print("Hot")
# elif temperature > 10:
#     print("Mild")
# elif temperature > 0:
#     print("Cold")
# else:
#     print("Freezing")
# ```

# %% [markdown]
# **Your prediction:** *(and: how many of the four lines print?)*

# %%
temperature = 15
if temperature > 30:
    print("Hot")
elif temperature > 10:
    print("Mild")
elif temperature > 0:
    print("Cold")
else:
    print("Freezing")

# %% [markdown]
# ### Warm-up 2
#
# ```python
# age = 20
# has_ticket = False
# print(age >= 18)
# print(age >= 18 and has_ticket)
# print(age >= 18 or has_ticket)
# print(not has_ticket)
# ```

# %% [markdown]
# **Your prediction:** *(four lines)*

# %%
age = 20
has_ticket = False
print(age >= 18)
print(age >= 18 and has_ticket)
print(age >= 18 or has_ticket)
print(not has_ticket)

# %% [markdown]
# ### Warm-up 3 — the classic
#
# ```python
# score = 95
# if score >= 50:
#     print("Pass")
# elif score >= 90:
#     print("Excellent")
# ```

# %% [markdown]
# **Your prediction:** *(this one is a trap — think about order)*

# %%
score = 95
if score >= 50:
    print("Pass")
elif score >= 90:
    print("Excellent")

# %% [markdown]
# **Q1 (written).** Warm-up 3 never prints `Excellent`, for **any** score. Explain why, and say
# what you would change.
#
# *Your answer:*

# %% [markdown]
# ---
#
# ## Part A — Making decisions
#
# ### A1 — Letter grades
#
# Set `letter` to the right grade for `score`, using the TRU-style scale:
#
# | Score | Letter |
# | :--- | :--- |
# | 90–100 | `"A"` |
# | 80–89 | `"B"` |
# | 70–79 | `"C"` |
# | 60–69 | `"D"` |
# | below 60 | `"F"` |
#
# Order your branches so that the first true one is the right one.

# %%
score = 87       # <-- change this and re-run to test other branches

# TODO: set letter using if / elif / else
letter = ""

print(score, "->", letter)

# %% [markdown]
# **Test every branch.** Change `score` above, re-run, and fill this table in with what your code
# actually printed. A branch you never ran is a branch you have not tested.
#
# | `score` | Your code printed | Should be |
# | :--- | :--- | :--- |
# | 95 | | A |
# | 90 | | A |
# | 89 | | B |
# | 60 | | D |
# | 59 | | F |
# | 0 | | F |

# %%
# ✅ Self-check A1 — leave score = 87 above before running this
assert letter == "B", "with score 87 your letter was " + str(letter)
print("All checks passed for score = 87 — but the table above is the real test.")

# %% [markdown]
# ### A2 — Two conditions at once
#
# A student may register for COMP 1110 if they are **admitted** *and* have **no unpaid fees**,
# **or** if they have a **dean's override** (which beats everything).
#
# Set `can_register` to `True` or `False`. Write it as **one boolean expression** — no `if`
# statement at all. This is the whole point of booleans: a condition is a value.

# %%
is_admitted = True
owes_fees = True
has_override = False

# TODO: one expression, using and / or / not
can_register = None

print("Can register:", can_register)

# %%
# ✅ Self-check A2 — with the three values set above
assert can_register is False, "can_register was " + str(can_register) + ", expected False"
assert (True and not False) or False, "sanity check"
print("All checks passed for this combination.")

# %% [markdown]
# One combination is not a test. Fill in the **truth table** by changing the three variables
# above and re-running. Eight rows, because three True/False inputs make 2 x 2 x 2 combinations:
#
# | `is_admitted` | `owes_fees` | `has_override` | Your `can_register` |
# | :--- | :--- | :--- | :--- |
# | True | False | False | |
# | True | True | False | |
# | True | True | True | |
# | False | False | False | |
# | False | True | True | |
# | False | False | True | |
# | True | False | True | |
# | False | True | False | |

# %% [markdown]
# ### A3 — `try` / `except`: never trust a typed number
#
# `int()` explodes if it is handed something that is not a number. Run this and read the error:

# %%
print(int("twelve"))

# %% [markdown]
# Now make it safe. If `typed` can be turned into an integer, set `age` to that integer;
# otherwise set `age` to `-1` and print a polite message.
#
# Test it with `"19"`, with `"nineteen"`, and with `""` (the empty string).

# %%
typed = "nineteen"     # <-- try "19", "nineteen", and ""

# TODO: use try / except to set age safely
age = None

print("age =", age)

# %%
# ✅ Self-check A3 — leave typed = "nineteen" above before running this
assert age == -1, "age was " + str(age) + ", expected -1 for bad input"
print("All checks passed for bad input — now set typed = \"19\" and re-run; age must be 19.")

# %% [markdown]
# ---
#
# ## 🎰 Part B — The Vending Machine
#
# Build a vending machine that decides what the customer gets. No loops yet — **one customer,
# one purchase**.
#
# The machine has three slots:
#
# | Code | Item | Price |
# | :--- | :--- | :--- |
# | `"A1"` | Chips | $2.25 |
# | `"A2"` | Chocolate | $2.75 |
# | `"B1"` | Water | $1.50 |
#
# **Rules, in order:**
#
# 1. If the code is not one of the three, print `Unknown code` and **refund everything**.
# 2. If the item is sold out, print `Sold out` and refund everything.
# 3. If the customer did not insert enough money, print how much **more** is needed and refund.
# 4. Otherwise: print the item and the **change** owed.
#
# Set `change_owed` to the money to hand back in every case (the full amount inserted, if the
# sale did not happen).

# %%
# --- the customer ---
code_entered = "A2"
money_inserted = 3.00

# --- the machine's stock ---
chips_in_stock = True
chocolate_in_stock = True
water_in_stock = False

# TODO: your vending machine logic.
# Set change_owed, and print exactly one outcome message.
change_owed = 0.0

# %%
# ✅ Self-check B — with code_entered = "A2" and money_inserted = 3.00
assert abs(change_owed - 0.25) < 0.001, "change_owed was " + str(change_owed)
print("All checks passed for the chocolate case.")

# %% [markdown]
# **Now test the other four outcomes yourself.** Change the values at the top of the cell,
# re-run, and record what happened:
#
# | `code_entered` | `money_inserted` | Stock | What your machine printed | `change_owed` |
# | :--- | :--- | :--- | :--- | :--- |
# | `"A2"` | 3.00 | in stock | | 0.25 |
# | `"B1"` | 2.00 | **sold out** | | 2.00 |
# | `"A1"` | 1.00 | in stock | | 1.00 |
# | `"C9"` | 5.00 | — | | 5.00 |
# | `"A1"` | 2.25 | in stock | | 0.00 |
#
# **Q2 (written).** The last row is the interesting one: the customer paid *exactly* the price.
# Does your machine sell it to them? If it does not, which comparison is wrong — and what does
# that tell you about `>` versus `>=`?
#
# *Your answer:*

# %% [markdown]
# ### B2 — Rock, Paper, Scissors judge
#
# One round. Two players' choices are already stored. Set `result` to exactly one of
# `"Player 1 wins"`, `"Player 2 wins"`, or `"Draw"`.
#
# Do it in **at most 6 lines** of `if`/`elif`/`else` — there are only three winning
# combinations, and a draw is any pair that is equal. Think before you type: a brute-force
# version needs nine branches, and a thoughtful one needs four.

# %%
player_one = "rock"
player_two = "scissors"

# TODO: set result
result = ""

print(player_one, "vs", player_two, "->", result)

# %%
# ✅ Self-check B2 — rock beats scissors
assert result == "Player 1 wins", "result was " + str(result)
print("All checks passed for rock vs scissors.")

# %% [markdown]
# Fill in every combination by changing the two variables and re-running. All nine:
#
# | P1 \ P2 | rock | paper | scissors |
# | :--- | :--- | :--- | :--- |
# | **rock** | | | |
# | **paper** | | | |
# | **scissors** | | | |

# %% [markdown]
# ---
#
# ## 🐛 Part C — Trace and explain

# %% [markdown]
# ### C1 — Trace by hand
#
# ```python
# x = 5
# y = 10
# if x > 3:
#     if y > 20:
#         print("both")
#     else:
#         print("first only")
# else:
#     print("neither")
# print("done")
# ```
#
# **What does it print, and in what order?** No running it.
#
# *Your answer:*

# %%
# Check yourself.
x = 5
y = 10
if x > 3:
    if y > 20:
        print("both")
    else:
        print("first only")
else:
    print("neither")
print("done")

# %% [markdown]
# ### C2 — Find the bug
#
# This is meant to print `Access granted` only for the correct password. Run it and watch it
# let everyone in.

# %%
password = "hunter2"
typed = "wrong-password"

if typed == "hunter2" or "HUNTER2":
    print("Access granted")
else:
    print("Access denied")

# %% [markdown]
# **Q3 (written).** The condition is legal Python, so there is no error message — just a security
# hole. Explain what `or "HUNTER2"` actually evaluates to and why that makes the whole condition
# always true. Then write the correct condition.
#
# *Your answer:*

# %%
# TODO: the fixed version. Test it with both the right and the wrong password.

# %% [markdown]
# ---
#
# ## 🤝 Part D — Team Arena: Break My Branch
#
# **You formed project teams on Thursday.** This is your team's first job together — and it is
# not writing code together, it is *testing* each other.
#
# **With your team (or on the Moodle forum thread `Week 3 — Break My Branch` if your team is not
# sorted yet):**
#
# 1. Each member posts **three inputs** for the vending machine — values of `code_entered`,
#    `money_inserted` and the stock flags — that they think will break somebody's machine.
#    Post the inputs and the outcome you *expect*, **never your code**.
# 2. Run **every** input your teammates posted through **your own** machine.
# 3. Record any disagreement between what you expected and what your machine did.
#
# Good inputs to think about: exactly the right money · negative money · a lowercase `"a1"` ·
# `"A1 "` with a trailing space · zero dollars · a code for a sold-out item with too little money
# (which rule wins?).
#
# **Bounty:** the input that breaks the most machines in the class gets read out in Tuesday's
# class, and we fix it together on the projector.

# %% [markdown]
# **Q4 (written).** Which teammate's input broke your machine (or came closest), what did your
# machine do, and what did you change?
#
# *Your answer:*

# %% [markdown]
# **Q5 (written).** Rule 4 of the vending machine says "otherwise". Suppose someone enters `"A1"`,
# inserts exactly $2.25, and chips are sold out. Which message should win, and why does the
# *order* of your `if` statements decide it? One or two sentences.
#
# *Your answer:*

# %% [markdown]
# ---
#
# ## ⭐ Bonus (0 marks) — The one-line adventure
#
# Extend the vending machine into a tiny **choose-your-own-adventure**: three or four nested
# decisions leading to at least four different endings. Keep it under 30 lines.
#
# Example shape (write your own story):
#
# > You reach a fork. `direction` is `"left"` or `"right"`.
# > Left: a bridge — do you have the rope? Right: a cave — is it daytime?
#
# This is nested `if` practice dressed up as a game, and it is genuinely good preparation for
# the text-adventure some of you will pick for the final project.

# %%
# TODO: your adventure. Change the variables at the top to walk different paths.
direction = "left"
has_rope = True
is_daytime = False

# %% [markdown]
# ---
#
# ## ✅ Before you submit
#
# Tick each one by replacing `[ ]` with `[x]` (double-click this cell to edit):
#
# - [ ] My name and student number are at the top.
# - [ ] I ran **every** cell from top to bottom, in order, with no errors.
# - [ ] Every **✅ Self-check** cell printed `All checks passed`.
# - [ ] I answered the written questions (they are marks too, not decoration).
# - [ ] I posted breaking inputs in **Week 3 — Break My Branch** and ran my teammates' inputs.
# - [ ] My variables have meaningful names — no `x`, `a`, `thing`.
# - [ ] I saved the notebook, and I am uploading the `.ipynb` file (not a screenshot, not a PDF).
#
# **Restart & Run All** is the honest test: *Kernel → Restart Kernel and Run All Cells*.
# If it fails there, it will fail when I mark it.

# %% [markdown]
# ## 🤖 AI acknowledgement
#
# Delete whichever line does not apply.
#
# > I did not use any AI tool on this worksheet.
#
# > **AI Acknowledgement:** This worksheet was completed with assistance from *[tool name and
# > version]*. I used it for *[e.g. explaining an error message, extra practice problems]*. All
# > AI-generated content was reviewed, verified, and edited by me, and I can explain every line
# > of the code I submitted.

# %% [markdown]
# ---
#
# ### Coming next
#
# **Week 4 — Functions.** Parameters, return values, and scope — the tool that makes testing all nine rock-paper-scissors combinations take one line instead of nine re-runs. Read [Chapter 4](https://books.trinket.io/pfe/04-functions.html).
#
# *Worksheet 3 of 11 · COMP 1110 · Fall 2026 · Quan Nguyen*
