# %% [markdown]
# # Worksheet 2 — The Mind Reader
#
# **COMP 1110 — Introduction to Computer Programming · Fall 2026**
# Instructor: **Quan Nguyen** · lnguyen[at]tru[dot]ca
#
# | | |
# | :--- | :--- |
# | **Covers** | variables, types, expressions, operators, `input()` and type conversion |
# | **Reading** | [Chapter 2 — Variables, expressions and statements](https://books.trinket.io/pfe/02-variables.html) |
# | **Released** | Thursday, September 17, 2026 |
# | **Due** | **Tuesday, September 22, 9:00 AM** — on the practice platform, before class |
# | **Worth** | 2% (your lowest worksheet score is dropped) |
#
# **Your name:** *(double-click this cell and type it here)*
#
# **Your student number:**

# %% [markdown]
# ## How to use this worksheet
#
# 1. **Run every cell as you go** — `Shift`+`Enter`. Nothing happens until you run it.
# 2. Wherever you see `# TODO`, that is your job. Replace it with your own code.
# 3. Cells marked **✅ Self-check** test your answer. If a self-check prints
#    `All checks passed`, that exercise is done. If it raises an `AssertionError`,
#    read the message — it tells you what was expected.
# 4. **Do the tasks on the [practice platform](http://134.87.8.19:8080)** — every exercise below is
#    there, it runs your code, checks it, and records what you have finished. That is your
#    worksheet: there is nothing to upload. Keep this notebook as your own copy.
#
# ### The rules (from the syllabus)
#
# - Talking through *approaches* with classmates is encouraged. **Writing the code together, or
#   copying it, is not.** Every line you submit must have come off your own keyboard.
# - The platform's **AI tutor** is the AI help for this course: it responds to every submission
#   with hints and questions, not answers. You must be able to explain every line you submit —
#   the midterms are closed-book, with no AI.
# - Marks are for **correct code** *and* **readable code**: meaningful names, and a comment
#   wherever the logic is not obvious.
#
# ⏱️ **Budget:** 60–90 minutes if you have done the reading. Stuck for more than 15 minutes on
# one part? Post on the Moodle forum — include your code *and* the full error message.

# %% [markdown]
# ### A note on `input()`
#
# Real programs ask the user for input. Inside a notebook, a waiting `input()` box is a
# nuisance, so this worksheet uses the same trick your lecture notebooks use:
#
# ```python
# age_text = "19"     # imagine the user typed this at an input() prompt
# ```
#
# Everything else about the program stays identical. At the very bottom of this worksheet
# there is an optional cell where you *do* use the real `input()`.

# %% [markdown]
# ---
#
# ## 🔥 Warm-up — Predict the output
#
# Read, predict, **then** run.

# %% [markdown]
# ### Warm-up 1
#
# ```python
# score = 10
# score = score + 5
# score = score * 2
# print(score)
# ```

# %% [markdown]
# **Your prediction:**

# %%
score = 10
score = score + 5
score = score * 2
print(score)

# %% [markdown]
# ### Warm-up 2
#
# ```python
# first = "COMP"
# second = 1110
# print(first + second)
# ```
#
# Careful — one of these is not like the other.

# %% [markdown]
# **Your prediction:** *(if you think it errors, say which error)*

# %%
first = "COMP"
second = 1110
print(first + second)

# %% [markdown]
# ### Warm-up 3
#
# ```python
# print(type(5))
# print(type(5.0))
# print(type("5"))
# print(int("5") + 5)
# ```

# %% [markdown]
# **Your prediction:**

# %%
print(type(5))
print(type(5.0))
print(type("5"))
print(int("5") + 5)

# %% [markdown]
# **Q1 (written).** `"5"` and `5` look the same on screen. Why does Python treat them so
# differently? Give one thing you can do with `5` that you cannot do with `"5"`.
#
# *Your answer:*

# %% [markdown]
# ---
#
# ## Part A — Variables that mean something
#
# A variable is a **name** for a value. The name is for humans; Python does not care.
# `d`, `x2` and `distance_km` all work — only one of them tells the person marking your code
# what you meant.

# %% [markdown]
# ### A2 — The road trip
#
# You are driving from **Kamloops to Vancouver: 355 km**. Your car uses **8.4 litres per
# 100 km**, and fuel costs **$1.65 per litre**.
#
# Create **four** well-named variables for those facts, then compute:
#
# - `litres_used` — the litres the trip needs
# - `fuel_cost` — the dollars it costs
#
# Do not type any number twice, and do not do arithmetic in your head. Then print a line like:
#
# ```text
# 355 km costs $ 49.19
# ```
#
# *(Rounding: use `round(fuel_cost, 2)`.)*

# %%
# TODO: four variables with meaningful names
distance_km = 0        # replace 0
litres_per_100km = 0   # replace 0
price_per_litre = 0    # replace 0

# TODO: two calculations
litres_used = 0
fuel_cost = 0

# TODO: print the summary line

# %%
# ✅ Self-check A2
assert distance_km == 355, "distance_km should be 355"
assert abs(litres_used - 29.82) < 0.01, "litres_used was " + str(litres_used)
assert abs(fuel_cost - 49.203) < 0.01, "fuel_cost was " + str(fuel_cost)
print("All checks passed")

# %% [markdown]
# ### A3 — Text in, number out
#
# `input()` **always** hands you a string, even when the user typed digits. Converting it is
# your job, and forgetting to is one of the most common bugs in this course.
#
# Below, two "typed" values arrive as text. Convert them and work out how many **full boxes**
# of cookies you can pack, and how many cookies are **left over**.

# %%
cookies_text = "137"    # imagine the user typed this
per_box_text = "12"     # ...and this

# TODO: convert both to integers
cookies = 0
per_box = 0

# TODO: full boxes (// ) and leftovers ( % )
full_boxes = 0
leftover = 0

print("Full boxes:", full_boxes)
print("Cookies left over:", leftover)

# %%
# ✅ Self-check A3
assert type(cookies) == int and type(per_box) == int, "convert the text to int first"
assert full_boxes == 11, "full_boxes was " + str(full_boxes) + ", expected 11"
assert leftover == 5, "leftover was " + str(leftover) + ", expected 5"
print("All checks passed")

# %% [markdown]
# ### A4 — The swap
#
# `hot` and `cold` got mixed up. Put them back the right way round.
#
# You may **not** retype the words `"soup"` or `"ice cream"` — you must move the values with
# variables. (There is a one-line Python trick for this; if you find it, lovely. If you use a
# third variable, that is the classic way and it is just as correct.)

# %%
hot = "ice cream"
cold = "soup"

# TODO: swap them

print("hot =", hot)
print("cold =", cold)

# %%
# ✅ Self-check A4
assert hot == "soup", "hot was " + str(hot)
assert cold == "ice cream", "cold was " + str(cold)
print("All checks passed")

# %% [markdown]
# ---
#
# ## 🎩 Part B — The Mind Reader
#
# Here is a trick you can do on a friend who has never seen it:
#
# > Think of any whole number. Don't tell me.
# > Double it. Add 10. Halve it. Now subtract the number you first thought of.
# > **You are thinking of 5.**
#
# It always lands on 5, whatever they started with. Your job: make Python do the trick, then
# build a *new* one of your own.

# %% [markdown]
# ### B1 — Make the trick run
#
# Fill in each step as its own line, using the previous variable each time. Change
# `secret_number` to anything you like and re-run: the answer must still be 5.

# %%
secret_number = 7        # your friend's secret — change it and re-run!

# TODO: one line per step of the trick
doubled = 0
plus_ten = 0
halved = 0
result = 0

print("You are thinking of:", result)

# %%
# ✅ Self-check B1 — the trick must work for a different secret number too
assert result == 5, "result was " + str(result) + ", expected 5"
check = (((99 * 2) + 10) / 2) - 99
assert check == 5, "sanity check of the maths"
print("All checks passed — now change secret_number to 3, then to 250, and re-run B1.")

# %% [markdown]
# **Q2 (written).** Explain *why* the trick always gives 5, in terms of the four steps. (Hint:
# write the steps out with the letter `n` instead of a number and simplify.) Then say what
# number the trick would land on if step 2 added **30** instead of 10.
#
# *Your answer:*

# %% [markdown]
# ### B2 — Invent your own trick
#
# Design a **different** number trick that always lands on a fixed value, and program it.
#
# Requirements:
#
# - At least **four** steps, each stored in its own well-named variable.
# - Must use at least two different operators (`+ - * / // % **`).
# - Must work for *any* starting number — prove it by running your cell three times with
#   wildly different secrets (try `0`, `-4`, `1000000`).
# - End by printing a dramatic reveal line.

# %%
# TODO: your own mind-reading trick
my_secret = 42

# ... your steps ...

print("The answer is:", None)   # replace None with your final variable

# %% [markdown]
# ---
#
# ## 🐛 Part C — Trace and explain
#
# Every worksheet has one of these, because the midterms are full of them and you may not run
# Python during a midterm.

# %% [markdown]
# ### C1 — Trace it by hand
#
# ```python
# apples = 3
# oranges = apples
# apples = apples + 4
# print(apples, oranges)
# ```
#
# Fill in the table by hand — no running it.
#
# | After line | `apples` | `oranges` |
# | :--- | :--- | :--- |
# | `apples = 3` | | |
# | `oranges = apples` | | |
# | `apples = apples + 4` | | |
#
# **What does it print?**
#
# *Your answer:*

# %%
# Now check yourself.
apples = 3
oranges = apples
apples = apples + 4
print(apples, oranges)

# %% [markdown]
# **Q3 (written).** Many people expect `oranges` to change too. In one sentence, say what the
# line `oranges = apples` actually did.
#
# *Your answer:*

# %% [markdown]
# ### C2 — Find the bug
#
# This program is supposed to add a **$5 delivery fee** to a pizza order and print the total.
# It runs, and the answer is wrong.

# %%
pizza_price_text = "18"     # imagine the user typed this
delivery_fee = 5

total = pizza_price_text + str(delivery_fee)
print("Total: $" + total)

# %% [markdown]
# **Q4 (written).** What did it print, what should it have printed, and what is the actual
# mistake? (It is not a missing `+`.)
#
# *Your answer:*

# %%
# TODO: the fixed version. It should print: Total: $23

# %% [markdown]
# ---
#
# ## ⭐ Bonus (0 marks) — for real this time
#
# Everything above faked `input()`. Run the cell below and answer the prompts for real. When you
# run it, a text box appears **at the top of the notebook** — type there and press Enter.
#
# If you would rather not have an input box in your saved notebook, leave this cell unrun.

# %%
# name = input("What is your name? ")
# secret_text = input("Think of a number and type it: ")
# secret = int(secret_text)
# print(name + ", you are thinking of:", (((secret * 2) + 10) / 2) - secret)

print("Uncomment the four lines above to run the trick on a real person.")

# %% [markdown]
# ---
#
# ## ✅ Before you submit
#
# Tick each one by replacing `[ ]` with `[x]` (double-click this cell to edit):
#
# - [ ] My name and student number are at the top.
# - [ ] I ran **every** cell from top to bottom, in order, with no errors.
# - [ ] Every **✅ Self-check** cell printed `All checks passed`.
# - [ ] I answered the written questions (they are marks too, not decoration).
# - [ ] My variables have meaningful names — no `x`, `a`, `thing`.
# - [ ] Every task for this worksheet is ✅ on the practice platform.
#
# **Restart & Run All** is the honest test: *Kernel → Restart Kernel and Run All Cells*.
# If it fails there, it will fail on the platform too.

# %% [markdown]
# ---
#
# ### Coming next
#
# **Week 3 — Conditionals.** `if`, `elif`, `else`, boolean logic, and `try`/`except` — how a program makes decisions. Read [Chapter 3](https://books.trinket.io/pfe/03-conditional.html). **Project teams are formed this week (Thursday, September 24)** — sit next to people you can work with.
#
# *Worksheet 2 of 11 · COMP 1110 · Fall 2026 · Quan Nguyen*
